# %% [markdown]
# # 5.2.8 Practical Activity

# %% [markdown]
# ## Practical activity: Search the Twitter API

# %% [markdown]
# ## 1 Prepare workstation

# %%
# Copy the YAML file and your Twitter keys over to this Jupyter Notebook before you start to work.
import yaml
from yaml.loader import SafeLoader
from twitter import *

# Import the YAML file - remember to specify the whole path.
twitter_creds = yaml.safe_load(open('mjh.yaml', 'r').read())

# Pass your Twitter credentials.
twitter_api = Twitter(auth=OAuth(twitter_creds['access_token'],
                                 twitter_creds['access_token_secret'], 
                                 twitter_creds['api_key'],
                                 twitter_creds['api_secret_key'] ))

# %%
# See if you are connected.
print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7faac862c610>

# %%
# Run a test with #python.
python_tweets = twitter_api.search.tweets(q="#python")

# View the output.
print(python_tweets)
# Out:
# {'statuses': [{'created_at': 'Fri Jul 01 10:10:35 +0000 2022', 'id': 1542812907037245441, 'id_str': '1542812907037245441', 'text': 'RT @sonu_monika: How #neurons really work is being elucidated?\nhttps://t.co/TmECSOFw5y #MachineLearning #Algorithms #DataScience #Python #P…', 'truncated': False, 'entities': {'hashtags': [{'text': 'neurons', 'indices': [21, 29]}, {'text': 'MachineLearning', 'indices': [87, 103]}, {'text': 'Algorithms', 'indices': [104, 115]}, {'text': 'DataScience', 'indices': [116, 128]}, {'text': 'Python', 'indices': [129, 136]}], 'symbols': [], 'user_mentions': [{'screen_name': 'sonu_monika', 'name': 'Dr. Monika Sonu, CEO Healthinnovationtoolbox', 'id': 1025638818068590592, 'id_str': '1025638818068590592', 'indices': [3, 15]}], 'urls': [{'url': 'https://t.co/TmECSOFw5y', 'expanded_url': 'https://www.economist.com/science-and-technology/2022/06/29/how-neurons-really-work-is-being-elucidated', 'display_url': 'economist.com/science-and-te…', 'indices': [63, 86]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://www.google.com" rel="nofollow">Xeron TweetBot</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1354047563280707586, 'id_str': '1354047563280707586', 'name': 'Xeron Bot', 'screen_name': 'XeronBot', 'location': 'Crawling Twitter', 'description': 'Beep! Boop!\nI am a Bot that likes and retweets latest tweets with #100DaysOfCode', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1680, 'friends_count': 1, 'listed_count': 22, 'created_at': 'Tue Jan 26 12:44:42 +0000 2021', 'favourites_count': 119758, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 467911, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1433726545466560518/ot8jDEO6_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1433726545466560518/ot8jDEO6_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1354047563280707586/1630662204', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Jul 01 08:38:06 +0000 2022', 'id': 1542789631405690880, 'id_str': '1542789631405690880', 'text': 'How #neurons really work is being elucidated?\nhttps://t.co/TmECSOFw5y #MachineLearning #Algorithms #DataScience… https://t.co/u9OaIBvzG2', 'truncated': True, 'entities': {'hashtags': [{'text': 'neurons', 'indices': [4, 12]}, {'text': 'MachineLearning', 'indices': [70, 86]}, {'text': 'Algorithms', 'indices': [87, 98]}, {'text': 'DataScience', 'indices': [99, 111]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/TmECSOFw5y', 'expanded_url': 'https://www.economist.com/science-and-technology/2022/06/29/how-neurons-really-work-is-being-elucidated', 'display_url': 'economist.com/science-and-te…', 'indices': [46, 69]}, {'url': 'https://t.co/u9OaIBvzG2', 'expanded_url': 'https://twitter.com/i/web/status/1542789631405690880', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [113, 136]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter ...

# %% [markdown]
# ## 2. Identify New York and London

# %%
# Determine worldwide trends.
trends_worldwide = twitter_api.trends.available()

# How many trends are available?
print(len(trends_worldwide))

# Example of trends_worldwide.
trends_worldwide[0]
# Out:
# 467
# {'name': 'Worldwide',
#  'placeType': {'code': 19, 'name': 'Supername'},
#  'url': 'http://where.yahooapis.com/v1/place/1',
#  'parentid': 0,
#  'country': '',
#  'woeid': 1,
#  'countryCode': None}

# %% [markdown]
# ## New York

# %%
# Find New York.
our_city = 'New York'

# Create a variable.
new_york = [_ for _ in trends_worldwide if _['name'] == our_city]

# View the output.
print(len(new_york))

# Use index to find New York.
new_york[0]

# List of where on earth identifier (woeid).
new_york[0]['woeid']
# Out:
# 1
# 2459115

# %% [markdown]
# ## London

# %%
# Find London.
our_city_2 = 'London'

# Create a variable.
london = [_ for _ in trends_worldwide if _['name'] == our_city_2]

# View the output.
print(len(london))

# Use index to find London.
london[0]

# List of where on earth identifier (woeid).
london[0]['woeid']
# Out:
# 1
# 44418

# %% [markdown]
# ## 3. Common trends

# %% [markdown]
# ## New York

# %%
# Look at trends in New York.
new_york_trends = twitter_api.trends.place(_id = new_york[0]['woeid'])

# View the output.
new_york_trends
# Out:
# [{'trends': [{'name': '#StrangerThings',
#     'url': 'http://twitter.com/search?q=%23StrangerThings',
#     'promoted_content': None,
#     'query': '%23StrangerThings',
#     'tweet_volume': 234598},
#    {'name': 'Eddie',
#     'url': 'http://twitter.com/search?q=Eddie',
#     'promoted_content': None,
#     'query': 'Eddie',
#     'tweet_volume': 185387},
#    {'name': 'Technoblade',
#     'url': 'http://twitter.com/search?q=Technoblade',
#     'promoted_content': None,
#     'query': 'Technoblade',
#     'tweet_volume': 925687},
#    {'name': 'hoseok',
#     'url': 'http://twitter.com/search?q=hoseok',
#     'promoted_content': None,
#     'query': 'hoseok',
#     'tweet_volume': 572567},
#    {'name': '#jhope_MORE',
#     'url': 'http://twitter.com/search?q=%23jhope_MORE',
#     'promoted_content': None,
#     'query': '%23jhope_MORE',
#     'tweet_volume': 1725569},
#    {'name': 'hobi',
#     'url': 'http://twitter.com/search?q=hobi',
#     'promoted_content': None,
#     'query': 'hobi',
#     'tweet_volume': 285436},
#    {'name': 'Happy Birthday Jordy',
#     'url': 'http://twitter.com/search?q=%22Happy+Birthday+Jordy%22',
#     'promoted_content': None,
#     'query': '%22Happy+Birthday+Jordy%22',
#     'tweet_volume': None},
#    {'name': 'hopper',
#     'url': 'http://twitter.com/search?q=hopper',
#     'promoted_content': None,
#     'query': 'hopper',
#     'tweet_volume': 29147},
#    {'name': 'Bobby Bonilla',
#     'url': 'http://twitter.com/search?q=%22Bobby+Bonilla%22',
#     'promoted_content': None,
#     'query': '%22Bobby+Bonilla%22',
#     'tweet_volume': None},
#    {'name': 'robin',
#     'url': 'http://twitter.com/search?q=robin',
#     'promoted_content': None,
#     'query': 'robin',
#     'tweet_volume': 112739},
#    {'name': 'joyce',
#     'url': 'http://twitter.com/search?q=joyce',
#     'promoted_content': None,
#     'query': 'joyce',
#     'tweet_volume': 28216},
#    {'name': 'Jonathan',
#     'url': 'http://twitter.com/search?q=Jonathan',
#     'promoted_content': None,
#     'query': 'Jonathan',
#     'tweet_volume': 52892},
#    {'name': '#TheBoys',
#     'url': 'http://twitter.com/search?q=%23TheBoys',
#     'promoted_content': None,
#     'query': '%23TheBoys',
#     'tweet_volume': 34605},
#    {'name': '#fridaymorning',
#     'url': 'http://twitter.com/search?q=%23fridaymorning',
#     'promoted_content': None,
#     'query': '%23fridaymorning',
#     'tweet_volume': None},
#    {'name': 'Lucas',
#     'url': 'http://twitter.com/search?q=Lucas',
#     'promoted_content': None,
#     'query': 'Lucas',
#     'tweet_volume': 146340},
#    {'name': 'Liberal World Order',
#     'url': 'http://twitter.com/search?q=%22Liberal+World+Order%22',
#     'promoted_content': None,
#     'query': '%22Liberal+World+Order%22',
#     'tweet_volume': 28158},
#    {'name': 'Cardi',
#     'url': 'http://twitter.com/search?q=Cardi',
#     'promoted_content': None,
#     'query': 'Cardi',
#     'tweet_volume': 81886},
#    {'name': 'dustin',
#     'url': 'http://twitter.com/search?q=dustin',
#     'promoted_content': None,
#     'query': 'dustin',
#     'tweet_volume': 34703},
#    {'name': 'byers',
#     'url': 'http://twitter.com/search?q=byers',
#     'promoted_content': None,
#     'query': 'byers',
#     'tweet_volume': 11715},
#    {'name': '#Wordle377',
#     'url': 'http://twitter.com/search?q=%23Wordle377',
#     'promoted_content': None,
#     'query': '%23Wordle377',
#     'tweet_volume': None},
#    {'name': 'Daily Quordle 158',
#     'url': 'http://twitter.com/search?q=%22Daily+Quordle+158%22',
#     'promoted_content': None,
#     'query': '%22Daily+Quordle+158%22',
#     'tweet_volume': None},
#    {'name': 'MASTER OF PUPPETS',
#     'url': 'http://twitter.com/search?q=%22MASTER+OF+PUPPETS%22',
#     'promoted_content': None,
#     'query': '%22MASTER+OF+PUPPETS%22',
#     'tweet_volume': None},
#    {'name': 'GPII',
#     'url': 'http://twitter.com/search?q=GPII',
#     'promoted_content': None,
#     'query': 'GPII',
#     'tweet_volume': None},
#    {'name': 'Minecraft',
#     'url': 'http://twitter.com/search?q=Minecraft',
#     'promoted_content': None,
#     'query': 'Minecraft',
#     'tweet_volume': 137154},
#    {'name': 'michael myers',
#     'url': 'http://twitter.com/search?q=%22michael+myers%22',
#     'promoted_content': None,
#     'query': '%22michael+myers%22',
#     'tweet_volume': None},
#    {'name': 'Brenner',
#     'url': 'http://twitter.com/search?q=Brenner',
#     'promoted_content': None,
#     'query': 'Brenner',
#     'tweet_volume': None},
#    {'name': 'enzo',
#     'url': 'http://twitter.com/search?q=enzo',
#     'promoted_content': None,
#     'query': 'enzo',
#     'tweet_volume': 21994},
#    {'name': 'THE PAINTING',
#     'url': 'http://twitter.com/search?q=%22THE+PAINTING%22',
#     'promoted_content': None,
#     'query': '%22THE+PAINTING%22',
#     'tweet_volume': 28347},
#    {'name': 'Not Netflix',
#     'url': 'http://twitter.com/search?q=%22Not+Netflix%22',
#     'promoted_content': None,
#     'query': '%22Not+Netflix%22',
#     'tweet_volume': None},
#    {'name': 'Miles Bridges',
#     'url': 'http://twitter.com/search?q=%22Miles+Bridges%22',
#     'promoted_content': None,
#     'query': '%22Miles+Bridges%22',
#     'tweet_volume': 42241},
#    {'name': 'Happy New Month',
#     'url': 'http://twitter.com/search?q=%22Happy+New+Month%22',
#     'promoted_content': None,
#     'query': '%22Happy+New+Month%22',
#     'tweet_volume': 83783},
#    {'name': 'Episode 8',
#     'url': 'http://twitter.com/search?q=%22Episode+8%22',
#     'promoted_content': None,
#     'query': '%22Episode+8%22',
#     'tweet_volume': None},
#    {'name': 'Vecna',
#     'url': 'http://twitter.com/search?q=Vecna',
#     'promoted_content': None,
#     'query': 'Vecna',
#     'tweet_volume': 85331},
#    {'name': 'My Netflix',
#     'url': 'http://twitter.com/search?q=%22My+Netflix%22',
#     'promoted_content': None,
#     'query': '%22My+Netflix%22',
#     'tweet_volume': 11404},
#    {'name': 'Separate Ways',
#     'url': 'http://twitter.com/search?q=%22Separate+Ways%22',
#     'promoted_content': None,
#     'query': '%22Separate+Ways%22',
#     'tweet_volume': None},
#    {'name': 'Argyle',
#     'url': 'http://twitter.com/search?q=Argyle',
#     'promoted_content': None,
#     'query': 'Argyle',
#     'tweet_volume': None},
#    {'name': 'steve harrington',
#     'url': 'http://twitter.com/search?q=%22steve+harrington%22',
#     'promoted_content': None,
#     'query': '%22steve+harrington%22',
#     'tweet_volume': 107159},
#    {'name': 'NETFLIX CRASHED',
#     'url': 'http://twitter.com/search?q=%22NETFLIX+CRASHED%22',
#     'promoted_content': None,
#     'query': '%22NETFLIX+CRASHED%22',
#     'tweet_volume': None},
#    {'name': 'Happy Canada',
#     'url': 'http://twitter.com/search?q=%22Happy+Canada%22',
#     'promoted_content': None,
#     'query': '%22Happy+Canada%22',
#     'tweet_volume': 13600},
#    {'name': 'Volume 2',
#     'url': 'http://twitter.com/search?q=%22Volume+2%22',
#     'promoted_content': None,
#     'query': '%22Volume+2%22',
#     'tweet_volume': 65244},
#    {'name': 'Rex Chapman',
#     'url': 'http://twitter.com/search?q=%22Rex+Chapman%22',
#     'promoted_content': None,
#     'query': '%22Rex+Chapman%22',
#     'tweet_volume': None},
#    {'name': 'vickie',
#     'url': 'http://twitter.com/search?q=vickie',
#     'promoted_content': None,
#     'query': 'vickie',
#     'tweet_volume': None},
#    {'name': 'Pink Friday',
#     'url': 'http://twitter.com/search?q=%22Pink+Friday%22',
#     'promoted_content': None,
#     'query': '%22Pink+Friday%22',
#     'tweet_volume': None},
#    {'name': 'millie bobby brown',
#     'url': 'http://twitter.com/search?q=%22millie+bobby+brown%22',
#     'promoted_content': None,
#     'query': '%22millie+bobby+brown%22',
#     'tweet_volume': None},
#    {'name': 'Erica',
#     'url': 'http://twitter.com/search?q=Erica',
#     'promoted_content': None,
#     'query': 'Erica',
#     'tweet_volume': 31864},
#    {'name': 'NICKI DAY',
#     'url': 'http://twitter.com/search?q=%22NICKI+DAY%22',
#     'promoted_content': None,
#     'query': '%22NICKI+DAY%22',
#     'tweet_volume': None},
#    {'name': 'eunwoo',
#     'url': 'http://twitter.com/search?q=eunwoo',
#     'promoted_content': None,
#     'query': 'eunwoo',
#     'tweet_volume': 35280},
#    {'name': 'david harbour',
#     'url': 'http://twitter.com/search?q=%22david+harbour%22',
#     'promoted_content': None,
#     'query': '%22david+harbour%22',
#     'tweet_volume': None},
#    {'name': 'Gary Payton',
#     'url': 'http://twitter.com/search?q=%22Gary+Payton%22',
#     'promoted_content': None,
#     'query': '%22Gary+Payton%22',
#     'tweet_volume': 13483},
#    {'name': 'Bahamas',
#     'url': 'http://twitter.com/search?q=Bahamas',
#     'promoted_content': None,
#     'query': 'Bahamas',
#     'tweet_volume': 11700}],
#   'as_of': '2022-07-01T10:12:32Z',
#   'created_at': '2022-06-29T13:35:46Z',
#   'locations': [{'name': 'New York', 'woeid': 2459115}]}]

# %%
# Look at the output as a DataFrame.
# Import Pandas.
import pandas as pd

# Create a DataFrame.
new_york_trends_pd = pd.DataFrame(new_york_trends[0]['trends'])

# View a DataFrame.
new_york_trends_pd
# Out:
#                     name                                                url  \
# 0        #StrangerThings      http://twitter.com/search?q=%23StrangerThings
# 1                  Eddie                  http://twitter.com/search?q=Eddie
# 2            Technoblade            http://twitter.com/search?q=Technoblade
# 3                 hoseok                 http://twitter.com/search?q=hoseok
# 4            #jhope_MORE          http://twitter.com/search?q=%23jhope_MORE
# 5                   hobi                   http://twitter.com/search?q=hobi
# 6   Happy Birthday Jordy  http://twitter.com/search?q=%22Happy+Birthday+...
# 7                 hopper                 http://twitter.com/search?q=hopper
# 8          Bobby Bonilla    http://twitter.com/search?q=%22Bobby+Bonilla%22
# 9                  robin                  http://twitter.com/search?q=robin
# 10                 joyce                  http://twitter.com/search?q=joyce
# 11              Jonathan               http://twitter.com/search?q=Jonathan
# 12              #TheBoys             http://twitter.com/search?q=%23TheBoys
# 13        #fridaymorning       http://twitter.com/search?q=%23fridaymorning
# 14                 Lucas                  http://twitter.com/search?q=Lucas
# 15   Liberal World Order  http://twitter.com/search?q=%22Liberal+World+O...
# 16                 Cardi                  http://twitter.com/search?q=Cardi
# 17                dustin                 http://twitter.com/search?q=dustin
# 18                 byers                  http://twitter.com/search?q=byers
# 19            #Wordle377           http://twitter.com/search?q=%23Wordle377
# 20     Daily Quordle 158  http://twitter.com/search?q=%22Daily+Quordle+1...
# 21     MASTER OF PUPPETS  http://twitter.com/search?q=%22MASTER+OF+PUPPE...
# 22                  GPII                   http://twitter.com/search?q=GPII
# 23             Minecraft              http://twitter.com/search?q=Minecraft
# 24         michael myers    http://twitter.com/search?q=%22michael+myers%22
# 25               Brenner                http://twitter.com/search?q=Brenner
# 26                  enzo                   http://twitter.com/search?q=enzo
# 27          THE PAINTING     http://twitter.com/search?q=%22THE+PAINTING%22
# 28           Not Netflix      http://twitter.com/search?q=%22Not+Netflix%22
# 29         Miles Bridges    http://twitter.com/search?q=%22Miles+Bridges%22
# 30       Happy New Month  http://twitter.com/search?q=%22Happy+New+Month%22
# 31             Episode 8        http://twitter.com/search?q=%22Episode+8%22
# 32                 Vecna                  http://twitter.com/search?q=Vecna
# 33            My Netflix       http://twitter.com/search?q=%22My+Netflix%22
# 34         Separate Ways    http://twitter.com/search?q=%22Separate+Ways%22
# 35                Argyle                 http://twitter.com/search?q=Argyle
# 36      steve harrington  http://twitter.com/search?q=%22steve+harringto...
# 37       NETFLIX CRASHED  http://twitter.com/search?q=%22NETFLIX+CRASHED%22
# 38          Happy Canada     http://twitter.com/search?q=%22Happy+Canada%22
# 39              Volume 2         http://twitter.com/search?q=%22Volume+2%22
# 40           Rex Chapman      http://twitter.com/search?q=%22Rex+Chapman%22
# 41                vickie                 http://twitter.com/search?q=vickie
# 42           Pink Friday      http://twitter.com/search?q=%22Pink+Friday%22
# 43    millie bobby brown  http://twitter.com/search?q=%22millie+bobby+br...
# 44                 Erica                  http://twitter.com/search?q=Erica
# 45             NICKI DAY        http://twitter.com/search?q=%22NICKI+DAY%22
# 46                eunwoo                 http://twitter.com/search?q=eunwoo
# 47         david harbour    http://twitter.com/search?q=%22david+harbour%22
# 48           Gary Payton      http://twitter.com/search?q=%22Gary+Payton%22
# 49               Bahamas                http://twitter.com/search?q=Bahamas
#
#    promoted_content                       query  tweet_volume
# 0              None           %23StrangerThings      234598.0
# 1              None                       Eddie      185387.0
# 2              None                 Technoblade      925687.0
# 3              None                      hoseok      572567.0
# 4              None               %23jhope_MORE     1725569.0
# 5              None                        hobi      285436.0
# 6              None  %22Happy+Birthday+Jordy%22           NaN
# 7              None                      hopper       29147.0
# 8              None         %22Bobby+Bonilla%22           NaN
# 9              None                       robin      112739.0
# 10             None                       joyce       28216.0
# 11             None                    Jonathan       52892.0
# 12             None                  %23TheBoys       34605.0
# 13             None            %23fridaymorning           NaN
# 14             None                       Lucas      146340.0
# 15             None   %22Liberal+World+Order%22       28158.0
# 16             None                       Cardi       81886.0
# 17             None                      dustin       34703.0
# 18             None                       byers       11715.0
# 19             None                %23Wordle377           NaN
# 20             None     %22Daily+Quordle+158%22           NaN
# 21             None     %22MASTER+OF+PUPPETS%22           NaN
# 22             None                        GPII           NaN
# 23             None                   Minecraft      137154.0
# 24             None         %22michael+myers%22           NaN
# 25             None                     Brenner           NaN
# 26             None                        enzo       21994.0
# 27             None          %22THE+PAINTING%22       28347.0
# 28             None           %22Not+Netflix%22           NaN
# 29             None         %22Miles+Bridges%22       42241.0
# 30             None       %22Happy+New+Month%22       83783.0
# 31             None             %22Episode+8%22           NaN
# 32             None                       Vecna       85331.0
# 33             None            %22My+Netflix%22       11404.0
# 34             None         %22Separate+Ways%22           NaN
# 35             None                      Argyle           NaN
# 36             None      %22steve+harrington%22      107159.0
# 37             None       %22NETFLIX+CRASHED%22           NaN
# 38             None          %22Happy+Canada%22       13600.0
# 39             None              %22Volume+2%22       65244.0
# 40             None           %22Rex+Chapman%22           NaN
# 41             None                      vickie           NaN
# 42             None           %22Pink+Friday%22           NaN
# 43             None    %22millie+bobby+brown%22           NaN
# 44             None                       Erica       31864.0
# 45             None             %22NICKI+DAY%22           NaN
# 46             None                      eunwoo       35280.0
# 47             None         %22david+harbour%22           NaN
# 48             None           %22Gary+Payton%22       13483.0
# 49             None                     Bahamas       11700.0

# %%
# Narrow list down to 50,000 tweets.
new_york_trends_over50k_pd = new_york_trends_pd[new_york_trends_pd['tweet_volume'] > 50000]\
.sort_values('tweet_volume', ascending=False)

# View the output.
print(new_york_trends_over50k_pd.shape)
new_york_trends_over50k_pd
# Out:
# (15, 5)
#                 name                                                url  \
# 4        #jhope_MORE          http://twitter.com/search?q=%23jhope_MORE
# 2        Technoblade            http://twitter.com/search?q=Technoblade
# 3             hoseok                 http://twitter.com/search?q=hoseok
# 5               hobi                   http://twitter.com/search?q=hobi
# 0    #StrangerThings      http://twitter.com/search?q=%23StrangerThings
# 1              Eddie                  http://twitter.com/search?q=Eddie
# 14             Lucas                  http://twitter.com/search?q=Lucas
# 23         Minecraft              http://twitter.com/search?q=Minecraft
# 9              robin                  http://twitter.com/search?q=robin
# 36  steve harrington  http://twitter.com/search?q=%22steve+harringto...
# 32             Vecna                  http://twitter.com/search?q=Vecna
# 30   Happy New Month  http://twitter.com/search?q=%22Happy+New+Month%22
# 16             Cardi                  http://twitter.com/search?q=Cardi
# 39          Volume 2         http://twitter.com/search?q=%22Volume+2%22
# 11          Jonathan               http://twitter.com/search?q=Jonathan
#
#    promoted_content                   query  tweet_volume
# 4              None           %23jhope_MORE     1725569.0
# 2              None             Technoblade      925687.0
# 3              None                  hoseok      572567.0
# 5              None                    hobi      285436.0
# 0              None       %23StrangerThings      234598.0
# 1              None                   Eddie      185387.0
# 14             None                   Lucas      146340.0
# 23             None               Minecraft      137154.0
# 9              None                   robin      112739.0
# 36             None  %22steve+harrington%22      107159.0
# 32             None                   Vecna       85331.0
# 30             None   %22Happy+New+Month%22       83783.0
# 16             None                   Cardi       81886.0
# 39             None          %22Volume+2%22       65244.0
# 11             None                Jonathan       52892.0

# %%
# Save output as a CSV file.
new_york_trends_over50k_pd.to_csv('new_york_trends_over50k.csv', index=False)

# %% [markdown]
# ## London

# %%
# Look at trends in London.
london = twitter_api.trends.place(_id = london[0]['woeid'])

# View the output.
london
# Out:
# [{'trends': [{'name': 'Andy Cole',
#     'url': 'http://twitter.com/search?q=%22Andy+Cole%22',
#     'promoted_content': None,
#     'query': '%22Andy+Cole%22',
#     'tweet_volume': None},
#    {'name': 'Sugababes',
#     'url': 'http://twitter.com/search?q=Sugababes',
#     'promoted_content': None,
#     'query': 'Sugababes',
#     'tweet_volume': None},
#    {'name': 'Morning Steve',
#     'url': 'http://twitter.com/search?q=%22Morning+Steve%22',
#     'promoted_content': None,
#     'query': '%22Morning+Steve%22',
#     'tweet_volume': None},
#    {'name': 'Spence',
#     'url': 'http://twitter.com/search?q=Spence',
#     'promoted_content': None,
#     'query': 'Spence',
#     'tweet_volume': 10493},
#    {'name': 'Jonathan',
#     'url': 'http://twitter.com/search?q=Jonathan',
#     'promoted_content': None,
#     'query': 'Jonathan',
#     'tweet_volume': 52892},
#    {'name': '#f122',
#     'url': 'http://twitter.com/search?q=%23f122',
#     'promoted_content': None,
#     'query': '%23f122',
#     'tweet_volume': 14874},
#    {'name': 'Usher',
#     'url': 'http://twitter.com/search?q=Usher',
#     'promoted_content': None,
#     'query': 'Usher',
#     'tweet_volume': 142800},
#    {'name': 'hopper',
#     'url': 'http://twitter.com/search?q=hopper',
#     'promoted_content': None,
#     'query': 'hopper',
#     'tweet_volume': 29147},
#    {'name': 'Board',
#     'url': 'http://twitter.com/search?q=Board',
#     'promoted_content': None,
#     'query': 'Board',
#     'tweet_volume': 151356},
#    {'name': '#Spurs',
#     'url': 'http://twitter.com/search?q=%23Spurs',
#     'promoted_content': None,
#     'query': '%23Spurs',
#     'tweet_volume': None},
#    {'name': 'Logan',
#     'url': 'http://twitter.com/search?q=Logan',
#     'promoted_content': None,
#     'query': 'Logan',
#     'tweet_volume': 39561},
#    {'name': 'Malacia',
#     'url': 'http://twitter.com/search?q=Malacia',
#     'promoted_content': None,
#     'query': 'Malacia',
#     'tweet_volume': 17190},
#    {'name': 'Minions',
#     'url': 'http://twitter.com/search?q=Minions',
#     'promoted_content': None,
#     'query': 'Minions',
#     'tweet_volume': 108001},
#    {'name': '#ENGvsIND',
#     'url': 'http://twitter.com/search?q=%23ENGvsIND',
#     'promoted_content': None,
#     'query': '%23ENGvsIND',
#     'tweet_volume': None},
#    {'name': '#StrangerThings',
#     'url': 'http://twitter.com/search?q=%23StrangerThings',
#     'promoted_content': None,
#     'query': '%23StrangerThings',
#     'tweet_volume': 234598},
#    {'name': 'Technoblade',
#     'url': 'http://twitter.com/search?q=Technoblade',
#     'promoted_content': None,
#     'query': 'Technoblade',
#     'tweet_volume': 925687},
#    {'name': 'Jota',
#     'url': 'http://twitter.com/search?q=Jota',
#     'promoted_content': None,
#     'query': 'Jota',
#     'tweet_volume': 22869},
#    {'name': "They're a 10",
#     'url': 'http://twitter.com/search?q=%22They%27re+a+10%22',
#     'promoted_content': None,
#     'query': '%22They%27re+a+10%22',
#     'tweet_volume': 15841},
#    {'name': 'ticketmaster',
#     'url': 'http://twitter.com/search?q=ticketmaster',
#     'promoted_content': None,
#     'query': 'ticketmaster',
#     'tweet_volume': None},
#    {'name': 'Somme',
#     'url': 'http://twitter.com/search?q=Somme',
#     'promoted_content': None,
#     'query': 'Somme',
#     'tweet_volume': None},
#    {'name': 'hoseok',
#     'url': 'http://twitter.com/search?q=hoseok',
#     'promoted_content': None,
#     'query': 'hoseok',
#     'tweet_volume': 572567},
#    {'name': '1st of July',
#     'url': 'http://twitter.com/search?q=%221st+of+July%22',
#     'promoted_content': None,
#     'query': '%221st+of+July%22',
#     'tweet_volume': 79722},
#    {'name': 'Daily Quordle 158',
#     'url': 'http://twitter.com/search?q=%22Daily+Quordle+158%22',
#     'promoted_content': None,
#     'query': '%22Daily+Quordle+158%22',
#     'tweet_volume': None},
#    {'name': 'Larsson',
#     'url': 'http://twitter.com/search?q=Larsson',
#     'promoted_content': None,
#     'query': 'Larsson',
#     'tweet_volume': None},
#    {'name': 'Tomiyasu',
#     'url': 'http://twitter.com/search?q=Tomiyasu',
#     'promoted_content': None,
#     'query': 'Tomiyasu',
#     'tweet_volume': None},
#    {'name': 'Belotti',
#     'url': 'http://twitter.com/search?q=Belotti',
#     'promoted_content': None,
#     'query': 'Belotti',
#     'tweet_volume': None},
#    {'name': 'hobi',
#     'url': 'http://twitter.com/search?q=hobi',
#     'promoted_content': None,
#     'query': 'hobi',
#     'tweet_volume': 285574},
#    {'name': 'Ben White',
#     'url': 'http://twitter.com/search?q=%22Ben+White%22',
#     'promoted_content': None,
#     'query': '%22Ben+White%22',
#     'tweet_volume': None},
#    {'name': 'Travis Scott',
#     'url': 'http://twitter.com/search?q=%22Travis+Scott%22',
#     'promoted_content': None,
#     'query': '%22Travis+Scott%22',
#     'tweet_volume': None},
#    {'name': 'Happy New Month',
#     'url': 'http://twitter.com/search?q=%22Happy+New+Month%22',
#     'promoted_content': None,
#     'query': '%22Happy+New+Month%22',
#     'tweet_volume': 83980},
#    {'name': 'ON SALE NOW',
#     'url': 'http://twitter.com/search?q=%22ON+SALE+NOW%22',
#     'promoted_content': None,
#     'query': '%22ON+SALE+NOW%22',
#     'tweet_volume': 16826},
#    {'name': 'Everton',
#     'url': 'http://twitter.com/search?q=Everton',
#     'promoted_content': None,
#     'query': 'Everton',
#     'tweet_volume': 49559},
#    {'name': 'Halifax',
#     'url': 'http://twitter.com/search?q=Halifax',
#     'promoted_content': None,
#     'query': 'Halifax',
#     'tweet_volume': 12225},
#    {'name': 'Stefan Ortega',
#     'url': 'http://twitter.com/search?q=%22Stefan+Ortega%22',
#     'promoted_content': None,
#     'query': '%22Stefan+Ortega%22',
#     'tweet_volume': None},
#    {'name': 'Lingard',
#     'url': 'http://twitter.com/search?q=Lingard',
#     'promoted_content': None,
#     'query': 'Lingard',
#     'tweet_volume': None},
#    {'name': 'Claudia Webbe',
#     'url': 'http://twitter.com/search?q=%22Claudia+Webbe%22',
#     'promoted_content': None,
#     'query': '%22Claudia+Webbe%22',
#     'tweet_volume': None},
#    {'name': 'Ederson',
#     'url': 'http://twitter.com/search?q=Ederson',
#     'promoted_content': None,
#     'query': 'Ederson',
#     'tweet_volume': None},
#    {'name': 'Edgbaston',
#     'url': 'http://twitter.com/search?q=Edgbaston',
#     'promoted_content': None,
#     'query': 'Edgbaston',
#     'tweet_volume': 16444},
#    {'name': 'Tour de France',
#     'url': 'http://twitter.com/search?q=%22Tour+de+France%22',
#     'promoted_content': None,
#     'query': '%22Tour+de+France%22',
#     'tweet_volume': 20314},
#    {'name': 'Mary Poppins',
#     'url': 'http://twitter.com/search?q=%22Mary+Poppins%22',
#     'promoted_content': None,
#     'query': '%22Mary+Poppins%22',
#     'tweet_volume': None},
#    {'name': 'Eddie',
#     'url': 'http://twitter.com/search?q=Eddie',
#     'promoted_content': None,
#     'query': 'Eddie',
#     'tweet_volume': 185696},
#    {'name': 'Hong Kong',
#     'url': 'http://twitter.com/search?q=%22Hong+Kong%22',
#     'promoted_content': None,
#     'query': '%22Hong+Kong%22',
#     'tweet_volume': 50511},
#    {'name': 'Vinted',
#     'url': 'http://twitter.com/search?q=Vinted',
#     'promoted_content': None,
#     'query': 'Vinted',
#     'tweet_volume': None},
#    {'name': 'Roger Moore',
#     'url': 'http://twitter.com/search?q=%22Roger+Moore%22',
#     'promoted_content': None,
#     'query': '%22Roger+Moore%22',
#     'tweet_volume': None},
#    {'name': 'Nancy',
#     'url': 'http://twitter.com/search?q=Nancy',
#     'promoted_content': None,
#     'query': 'Nancy',
#     'tweet_volume': 93250},
#    {'name': 'Whip',
#     'url': 'http://twitter.com/search?q=Whip',
#     'promoted_content': None,
#     'query': 'Whip',
#     'tweet_volume': 64673},
#    {'name': 'Hairdresser',
#     'url': 'http://twitter.com/search?q=Hairdresser',
#     'promoted_content': None,
#     'query': 'Hairdresser',
#     'tweet_volume': None},
#    {'name': 'White Rabbits',
#     'url': 'http://twitter.com/search?q=%22White+Rabbits%22',
#     'promoted_content': None,
#     'query': '%22White+Rabbits%22',
#     'tweet_volume': None},
#    {'name': 'Richy',
#     'url': 'http://twitter.com/search?q=Richy',
#     'promoted_content': None,
#     'query': 'Richy',
#     'tweet_volume': None}],
#   'as_of': '2022-07-01T10:12:54Z',
#   'created_at': '2022-06-14T02:54:46Z',
#   'locations': [{'name': 'London', 'woeid': 44418}]}]

# %%
# Look at the output as a DataFrame.

# Create a DataFrame.
london_trends_pd = pd.DataFrame(london[0]['trends'])

# View the DataFrame.
london_trends_pd
# Out:
#                  name                                                url  \
# 0           Andy Cole        http://twitter.com/search?q=%22Andy+Cole%22
# 1           Sugababes              http://twitter.com/search?q=Sugababes
# 2       Morning Steve    http://twitter.com/search?q=%22Morning+Steve%22
# 3              Spence                 http://twitter.com/search?q=Spence
# 4            Jonathan               http://twitter.com/search?q=Jonathan
# 5               #f122                http://twitter.com/search?q=%23f122
# 6               Usher                  http://twitter.com/search?q=Usher
# 7              hopper                 http://twitter.com/search?q=hopper
# 8               Board                  http://twitter.com/search?q=Board
# 9              #Spurs               http://twitter.com/search?q=%23Spurs
# 10              Logan                  http://twitter.com/search?q=Logan
# 11            Malacia                http://twitter.com/search?q=Malacia
# 12            Minions                http://twitter.com/search?q=Minions
# 13          #ENGvsIND            http://twitter.com/search?q=%23ENGvsIND
# 14    #StrangerThings      http://twitter.com/search?q=%23StrangerThings
# 15        Technoblade            http://twitter.com/search?q=Technoblade
# 16               Jota                   http://twitter.com/search?q=Jota
# 17       They're a 10   http://twitter.com/search?q=%22They%27re+a+10%22
# 18       ticketmaster           http://twitter.com/search?q=ticketmaster
# 19              Somme                  http://twitter.com/search?q=Somme
# 20             hoseok                 http://twitter.com/search?q=hoseok
# 21        1st of July      http://twitter.com/search?q=%221st+of+July%22
# 22  Daily Quordle 158  http://twitter.com/search?q=%22Daily+Quordle+1...
# 23            Larsson                http://twitter.com/search?q=Larsson
# 24           Tomiyasu               http://twitter.com/search?q=Tomiyasu
# 25            Belotti                http://twitter.com/search?q=Belotti
# 26               hobi                   http://twitter.com/search?q=hobi
# 27          Ben White        http://twitter.com/search?q=%22Ben+White%22
# 28       Travis Scott     http://twitter.com/search?q=%22Travis+Scott%22
# 29    Happy New Month  http://twitter.com/search?q=%22Happy+New+Month%22
# 30        ON SALE NOW      http://twitter.com/search?q=%22ON+SALE+NOW%22
# 31            Everton                http://twitter.com/search?q=Everton
# 32            Halifax                http://twitter.com/search?q=Halifax
# 33      Stefan Ortega    http://twitter.com/search?q=%22Stefan+Ortega%22
# 34            Lingard                http://twitter.com/search?q=Lingard
# 35      Claudia Webbe    http://twitter.com/search?q=%22Claudia+Webbe%22
# 36            Ederson                http://twitter.com/search?q=Ederson
# 37          Edgbaston              http://twitter.com/search?q=Edgbaston
# 38     Tour de France   http://twitter.com/search?q=%22Tour+de+France%22
# 39       Mary Poppins     http://twitter.com/search?q=%22Mary+Poppins%22
# 40              Eddie                  http://twitter.com/search?q=Eddie
# 41          Hong Kong        http://twitter.com/search?q=%22Hong+Kong%22
# 42             Vinted                 http://twitter.com/search?q=Vinted
# 43        Roger Moore      http://twitter.com/search?q=%22Roger+Moore%22
# 44              Nancy                  http://twitter.com/search?q=Nancy
# 45               Whip                   http://twitter.com/search?q=Whip
# 46        Hairdresser            http://twitter.com/search?q=Hairdresser
# 47      White Rabbits    http://twitter.com/search?q=%22White+Rabbits%22
# 48              Richy                  http://twitter.com/search?q=Richy
#
#    promoted_content                    query  tweet_volume
# 0              None          %22Andy+Cole%22           NaN
# 1              None                Sugababes           NaN
# 2              None      %22Morning+Steve%22           NaN
# 3              None                   Spence       10493.0
# 4              None                 Jonathan       52892.0
# 5              None                  %23f122       14874.0
# 6              None                    Usher      142800.0
# 7              None                   hopper       29147.0
# 8              None                    Board      151356.0
# 9              None                 %23Spurs           NaN
# 10             None                    Logan       39561.0
# 11             None                  Malacia       17190.0
# 12             None                  Minions      108001.0
# 13             None              %23ENGvsIND           NaN
# 14             None        %23StrangerThings      234598.0
# 15             None              Technoblade      925687.0
# 16             None                     Jota       22869.0
# 17             None     %22They%27re+a+10%22       15841.0
# 18             None             ticketmaster           NaN
# 19             None                    Somme           NaN
# 20             None                   hoseok      572567.0
# 21             None        %221st+of+July%22       79722.0
# 22             None  %22Daily+Quordle+158%22           NaN
# 23             None                  Larsson           NaN
# 24             None                 Tomiyasu           NaN
# 25             None                  Belotti           NaN
# 26             None                     hobi      285574.0
# 27             None          %22Ben+White%22           NaN
# 28             None       %22Travis+Scott%22           NaN
# 29             None    %22Happy+New+Month%22       83980.0
# 30             None        %22ON+SALE+NOW%22       16826.0
# 31             None                  Everton       49559.0
# 32             None                  Halifax       12225.0
# 33             None      %22Stefan+Ortega%22           NaN
# 34             None                  Lingard           NaN
# 35             None      %22Claudia+Webbe%22           NaN
# 36             None                  Ederson           NaN
# 37             None                Edgbaston       16444.0
# 38             None     %22Tour+de+France%22       20314.0
# 39             None       %22Mary+Poppins%22           NaN
# 40             None                    Eddie      185696.0
# 41             None          %22Hong+Kong%22       50511.0
# 42             None                   Vinted           NaN
# 43             None        %22Roger+Moore%22           NaN
# 44             None                    Nancy       93250.0
# 45             None                     Whip       64673.0
# 46             None              Hairdresser           NaN
# 47             None      %22White+Rabbits%22           NaN
# 48             None                    Richy           NaN

# %%
# Narrow list down to 50,000 tweets.
london_trends_over50k_pd = london_trends_pd[london_trends_pd['tweet_volume'] > 50000]\
.sort_values('tweet_volume', ascending=False)

# View the output.
print(london_trends_over50k_pd.shape)
london_trends_over50k_pd
# Out:
# (14, 5)
#                name                                                url  \
# 15      Technoblade            http://twitter.com/search?q=Technoblade
# 20           hoseok                 http://twitter.com/search?q=hoseok
# 26             hobi                   http://twitter.com/search?q=hobi
# 14  #StrangerThings      http://twitter.com/search?q=%23StrangerThings
# 40            Eddie                  http://twitter.com/search?q=Eddie
# 8             Board                  http://twitter.com/search?q=Board
# 6             Usher                  http://twitter.com/search?q=Usher
# 12          Minions                http://twitter.com/search?q=Minions
# 44            Nancy                  http://twitter.com/search?q=Nancy
# 29  Happy New Month  http://twitter.com/search?q=%22Happy+New+Month%22
# 21      1st of July      http://twitter.com/search?q=%221st+of+July%22
# 45             Whip                   http://twitter.com/search?q=Whip
# 4          Jonathan               http://twitter.com/search?q=Jonathan
# 41        Hong Kong        http://twitter.com/search?q=%22Hong+Kong%22
#
#    promoted_content                  query  tweet_volume
# 15             None            Technoblade      925687.0
# 20             None                 hoseok      572567.0
# 26             None                   hobi      285574.0
# 14             None      %23StrangerThings      234598.0
# 40             None                  Eddie      185696.0
# 8              None                  Board      151356.0
# 6              None                  Usher      142800.0
# 12             None                Minions      108001.0
# 44             None                  Nancy       93250.0
# 29             None  %22Happy+New+Month%22       83980.0
# 21             None      %221st+of+July%22       79722.0
# 45             None                   Whip       64673.0
# 4              None               Jonathan       52892.0
# 41             None        %22Hong+Kong%22       50511.0

# %%
# Save output as a CSV file.
london_trends_over50k_pd.to_csv('london_trends_over50k.csv', index=False)

# %% [markdown]
# ### compare cities

# %%
# Find New York.
our_city = 'New York'

# Create a variable.
new_york = [_ for _ in trends_worldwide if _['name'] == our_city]

# View the output.
new_york[0]['woeid']
# Out:
# 2459115

# %%
# Find London.
our_city_2 = 'London'

# Create a variable.
london = [_ for _ in trends_worldwide if _['name'] == our_city_2]

# View the output.
london[0]['woeid']
# Out:
# 44418

# %%
# Search for each city.
# Import JSON.
import json

# Search for New York.
new_york_trends = twitter_api.trends.place(_id=2459115)

# View JSON output.
print (json.dumps(new_york_trends, indent=4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "#StrangerThings",
#                 "url": "http://twitter.com/search?q=%23StrangerThings",
#                 "promoted_content": null,
#                 "query": "%23StrangerThings",
#                 "tweet_volume": 235521
#             },
#             {
#                 "name": "Eddie",
#                 "url": "http://twitter.com/search?q=Eddie",
#                 "promoted_content": null,
#                 "query": "Eddie",
#                 "tweet_volume": 185696
#             },
#             {
#                 "name": "Technoblade",
#                 "url": "http://twitter.com/search?q=Technoblade",
#                 "promoted_content": null,
#                 "query": "Technoblade",
#                 "tweet_volume": 926515
#             },
#             {
#                 "name": "hoseok",
#                 "url": "http://twitter.com/search?q=hoseok",
#                 "promoted_content": null,
#                 "query": "hoseok",
#                 "tweet_volume": 572830
#             },
#             {
#                 "name": "#jhope_MORE",
#                 "url": "http://twitter.com/search?q=%23jhope_MORE",
#                 "promoted_content": null,
#                 "query": "%23jhope_MORE",
#                 "tweet_volume": 1713424
#             },
#             {
#                 "name": "hobi",
#                 "url": "http://twitter.com/search?q=hobi",
#                 "promoted_content": null,
#                 "query": "hobi",
#                 "tweet_volume": 285701
#             },
#             {
#                 "name": "Happy Birthday Jordy",
#                 "url": "http://twitter.com/search?q=%22Happy+Birthday+Jordy%22",
#                 "promoted_content": null,
#                 "query": "%22Happy+Birthday+Jordy%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "hopper",
#                 "url": "http://twitter.com/search?q=hopper",
#                 "promoted_content": null,
#                 "query": "hopper",
#                 "tweet_volume": 29186
#             },
#             {
#                 "name": "Bobby Bonilla",
#                 "url": "http://twitter.com/search?q=%22Bobby+Bonilla%22",
#                 "promoted_content": null,
#                 "query": "%22Bobby+Bonilla%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "robin",
#                 "url": "http://twitter.com/search?q=robin",
#                 "promoted_content": null,
#                 "query": "robin",
#                 "tweet_volume": 112739
#             },
#             {
#                 "name": "joyce",
#                 "url": "http://twitter.com/search?q=joyce",
#                 "promoted_content": null,
#                 "query": "joyce",
#                 "tweet_volume": 28239
#             },
#             {
#                 "name": "Jonathan",
#                 "url": "http://twitter.com/search?q=Jonathan",
#                 "promoted_content": null,
#                 "query": "Jonathan",
#                 "tweet_volume": 52940
#             },
#             {
#                 "name": "#TheBoys",
#                 "url": "http://twitter.com/search?q=%23TheBoys",
#                 "promoted_content": null,
#                 "query": "%23TheBoys",
#                 "tweet_volume": 34635
#             },
#             {
#                 "name": "#fridaymorning",
#                 "url": "http://twitter.com/search?q=%23fridaymorning",
#                 "promoted_content": null,
#                 "query": "%23fridaymorning",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Lucas",
#                 "url": "http://twitter.com/search?q=Lucas",
#                 "promoted_content": null,
#                 "query": "Lucas",
#                 "tweet_volume": 146434
#             },
#             {
#                 "name": "Liberal World Order",
#                 "url": "http://twitter.com/search?q=%22Liberal+World+Order%22",
#                 "promoted_content": null,
#                 "query": "%22Liberal+World+Order%22",
#                 "tweet_volume": 28183
#             },
#             {
#                 "name": "Cardi",
#                 "url": "http://twitter.com/search?q=Cardi",
#                 "promoted_content": null,
#                 "query": "Cardi",
#                 "tweet_volume": 81886
#             },
#             {
#                 "name": "dustin",
#                 "url": "http://twitter.com/search?q=dustin",
#                 "promoted_content": null,
#                 "query": "dustin",
#                 "tweet_volume": 34747
#             },
#             {
#                 "name": "byers",
#                 "url": "http://twitter.com/search?q=byers",
#                 "promoted_content": null,
#                 "query": "byers",
#                 "tweet_volume": 11729
#             },
#             {
#                 "name": "#Wordle377",
#                 "url": "http://twitter.com/search?q=%23Wordle377",
#                 "promoted_content": null,
#                 "query": "%23Wordle377",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Daily Quordle 158",
#                 "url": "http://twitter.com/search?q=%22Daily+Quordle+158%22",
#                 "promoted_content": null,
#                 "query": "%22Daily+Quordle+158%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "MASTER OF PUPPETS",
#                 "url": "http://twitter.com/search?q=%22MASTER+OF+PUPPETS%22",
#                 "promoted_content": null,
#                 "query": "%22MASTER+OF+PUPPETS%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "GPII",
#                 "url": "http://twitter.com/search?q=GPII",
#                 "promoted_content": null,
#                 "query": "GPII",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Minecraft",
#                 "url": "http://twitter.com/search?q=Minecraft",
#                 "promoted_content": null,
#                 "query": "Minecraft",
#                 "tweet_volume": 137252
#             },
#             {
#                 "name": "michael myers",
#                 "url": "http://twitter.com/search?q=%22michael+myers%22",
#                 "promoted_content": null,
#                 "query": "%22michael+myers%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Brenner",
#                 "url": "http://twitter.com/search?q=Brenner",
#                 "promoted_content": null,
#                 "query": "Brenner",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "enzo",
#                 "url": "http://twitter.com/search?q=enzo",
#                 "promoted_content": null,
#                 "query": "enzo",
#                 "tweet_volume": 21994
#             },
#             {
#                 "name": "THE PAINTING",
#                 "url": "http://twitter.com/search?q=%22THE+PAINTING%22",
#                 "promoted_content": null,
#                 "query": "%22THE+PAINTING%22",
#                 "tweet_volume": 28382
#             },
#             {
#                 "name": "Not Netflix",
#                 "url": "http://twitter.com/search?q=%22Not+Netflix%22",
#                 "promoted_content": null,
#                 "query": "%22Not+Netflix%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Miles Bridges",
#                 "url": "http://twitter.com/search?q=%22Miles+Bridges%22",
#                 "promoted_content": null,
#                 "query": "%22Miles+Bridges%22",
#                 "tweet_volume": 42241
#             },
#             {
#                 "name": "Happy New Month",
#                 "url": "http://twitter.com/search?q=%22Happy+New+Month%22",
#                 "promoted_content": null,
#                 "query": "%22Happy+New+Month%22",
#                 "tweet_volume": 83980
#             },
#             {
#                 "name": "Episode 8",
#                 "url": "http://twitter.com/search?q=%22Episode+8%22",
#                 "promoted_content": null,
#                 "query": "%22Episode+8%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Vecna",
#                 "url": "http://twitter.com/search?q=Vecna",
#                 "promoted_content": null,
#                 "query": "Vecna",
#                 "tweet_volume": 85331
#             },
#             {
#                 "name": "My Netflix",
#                 "url": "http://twitter.com/search?q=%22My+Netflix%22",
#                 "promoted_content": null,
#                 "query": "%22My+Netflix%22",
#                 "tweet_volume": 11411
#             },
#             {
#                 "name": "Separate Ways",
#                 "url": "http://twitter.com/search?q=%22Separate+Ways%22",
#                 "promoted_content": null,
#                 "query": "%22Separate+Ways%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Argyle",
#                 "url": "http://twitter.com/search?q=Argyle",
#                 "promoted_content": null,
#                 "query": "Argyle",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Happy Canada",
#                 "url": "http://twitter.com/search?q=%22Happy+Canada%22",
#                 "promoted_content": null,
#                 "query": "%22Happy+Canada%22",
#                 "tweet_volume": 13600
#             },
#             {
#                 "name": "NETFLIX CRASHED",
#                 "url": "http://twitter.com/search?q=%22NETFLIX+CRASHED%22",
#                 "promoted_content": null,
#                 "query": "%22NETFLIX+CRASHED%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Pink Friday",
#                 "url": "http://twitter.com/search?q=%22Pink+Friday%22",
#                 "promoted_content": null,
#                 "query": "%22Pink+Friday%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Volume 2",
#                 "url": "http://twitter.com/search?q=%22Volume+2%22",
#                 "promoted_content": null,
#                 "query": "%22Volume+2%22",
#                 "tweet_volume": 65285
#             },
#             {
#                 "name": "steve harrington",
#                 "url": "http://twitter.com/search?q=%22steve+harrington%22",
#                 "promoted_content": null,
#                 "query": "%22steve+harrington%22",
#                 "tweet_volume": 107159
#             },
#             {
#                 "name": "Rex Chapman",
#                 "url": "http://twitter.com/search?q=%22Rex+Chapman%22",
#                 "promoted_content": null,
#                 "query": "%22Rex+Chapman%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "vickie",
#                 "url": "http://twitter.com/search?q=vickie",
#                 "promoted_content": null,
#                 "query": "vickie",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "millie bobby brown",
#                 "url": "http://twitter.com/search?q=%22millie+bobby+brown%22",
#                 "promoted_content": null,
#                 "query": "%22millie+bobby+brown%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Erica",
#                 "url": "http://twitter.com/search?q=Erica",
#                 "promoted_content": null,
#                 "query": "Erica",
#                 "tweet_volume": 31864
#             },
#             {
#                 "name": "NICKI DAY",
#                 "url": "http://twitter.com/search?q=%22NICKI+DAY%22",
#                 "promoted_content": null,
#                 "query": "%22NICKI+DAY%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "eunwoo",
#                 "url": "http://twitter.com/search?q=eunwoo",
#                 "promoted_content": null,
#                 "query": "eunwoo",
#                 "tweet_volume": 35280
#             },
#             {
#                 "name": "david harbour",
#                 "url": "http://twitter.com/search?q=%22david+harbour%22",
#                 "promoted_content": null,
#                 "query": "%22david+harbour%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Gary Payton",
#                 "url": "http://twitter.com/search?q=%22Gary+Payton%22",
#                 "promoted_content": null,
#                 "query": "%22Gary+Payton%22",
#                 "tweet_volume": 13494
#             },
#             {
#                 "name": "Bino",
#                 "url": "http://twitter.com/search?q=Bino",
#                 "promoted_content": null,
#                 "query": "Bino",
#                 "tweet_volume": null
#             }
#         ],
#         "as_of": "2022-07-01T10:13:16Z",
#         "created_at": "2022-06-29T13:35:46Z",
#         "locations": [
#             {
#                 "name": "New York",
#                 "woeid": 2459115
#             }
#         ]
#     }
# ]

# %%
# Search for London.
london_trends = twitter_api.trends.place(_id=44418)

# View JSON output.
print (json.dumps(london_trends, indent=4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "Andy Cole",
#                 "url": "http://twitter.com/search?q=%22Andy+Cole%22",
#                 "promoted_content": null,
#                 "query": "%22Andy+Cole%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Sugababes",
#                 "url": "http://twitter.com/search?q=Sugababes",
#                 "promoted_content": null,
#                 "query": "Sugababes",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Morning Steve",
#                 "url": "http://twitter.com/search?q=%22Morning+Steve%22",
#                 "promoted_content": null,
#                 "query": "%22Morning+Steve%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Spence",
#                 "url": "http://twitter.com/search?q=Spence",
#                 "promoted_content": null,
#                 "query": "Spence",
#                 "tweet_volume": 10498
#             },
#             {
#                 "name": "Jonathan",
#                 "url": "http://twitter.com/search?q=Jonathan",
#                 "promoted_content": null,
#                 "query": "Jonathan",
#                 "tweet_volume": 52991
#             },
#             {
#                 "name": "#F122",
#                 "url": "http://twitter.com/search?q=%23F122",
#                 "promoted_content": null,
#                 "query": "%23F122",
#                 "tweet_volume": 14897
#             },
#             {
#                 "name": "Usher",
#                 "url": "http://twitter.com/search?q=Usher",
#                 "promoted_content": null,
#                 "query": "Usher",
#                 "tweet_volume": 142887
#             },
#             {
#                 "name": "hopper",
#                 "url": "http://twitter.com/search?q=hopper",
#                 "promoted_content": null,
#                 "query": "hopper",
#                 "tweet_volume": 29217
#             },
#             {
#                 "name": "Board",
#                 "url": "http://twitter.com/search?q=Board",
#                 "promoted_content": null,
#                 "query": "Board",
#                 "tweet_volume": 151465
#             },
#             {
#                 "name": "#Spurs",
#                 "url": "http://twitter.com/search?q=%23Spurs",
#                 "promoted_content": null,
#                 "query": "%23Spurs",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Logan",
#                 "url": "http://twitter.com/search?q=Logan",
#                 "promoted_content": null,
#                 "query": "Logan",
#                 "tweet_volume": 39585
#             },
#             {
#                 "name": "Malacia",
#                 "url": "http://twitter.com/search?q=Malacia",
#                 "promoted_content": null,
#                 "query": "Malacia",
#                 "tweet_volume": 17475
#             },
#             {
#                 "name": "Minions",
#                 "url": "http://twitter.com/search?q=Minions",
#                 "promoted_content": null,
#                 "query": "Minions",
#                 "tweet_volume": 108131
#             },
#             {
#                 "name": "#ENGvsIND",
#                 "url": "http://twitter.com/search?q=%23ENGvsIND",
#                 "promoted_content": null,
#                 "query": "%23ENGvsIND",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "#StrangerThings",
#                 "url": "http://twitter.com/search?q=%23StrangerThings",
#                 "promoted_content": null,
#                 "query": "%23StrangerThings",
#                 "tweet_volume": 235960
#             },
#             {
#                 "name": "Technoblade",
#                 "url": "http://twitter.com/search?q=Technoblade",
#                 "promoted_content": null,
#                 "query": "Technoblade",
#                 "tweet_volume": 927732
#             },
#             {
#                 "name": "Jota",
#                 "url": "http://twitter.com/search?q=Jota",
#                 "promoted_content": null,
#                 "query": "Jota",
#                 "tweet_volume": 22969
#             },
#             {
#                 "name": "They're a 10",
#                 "url": "http://twitter.com/search?q=%22They%27re+a+10%22",
#                 "promoted_content": null,
#                 "query": "%22They%27re+a+10%22",
#                 "tweet_volume": 15867
#             },
#             {
#                 "name": "ticketmaster",
#                 "url": "http://twitter.com/search?q=ticketmaster",
#                 "promoted_content": null,
#                 "query": "ticketmaster",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Somme",
#                 "url": "http://twitter.com/search?q=Somme",
#                 "promoted_content": null,
#                 "query": "Somme",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "hoseok",
#                 "url": "http://twitter.com/search?q=hoseok",
#                 "promoted_content": null,
#                 "query": "hoseok",
#                 "tweet_volume": 572830
#             },
#             {
#                 "name": "1st of July",
#                 "url": "http://twitter.com/search?q=%221st+of+July%22",
#                 "promoted_content": null,
#                 "query": "%221st+of+July%22",
#                 "tweet_volume": 79799
#             },
#             {
#                 "name": "Daily Quordle 158",
#                 "url": "http://twitter.com/search?q=%22Daily+Quordle+158%22",
#                 "promoted_content": null,
#                 "query": "%22Daily+Quordle+158%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Larsson",
#                 "url": "http://twitter.com/search?q=Larsson",
#                 "promoted_content": null,
#                 "query": "Larsson",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Tomiyasu",
#                 "url": "http://twitter.com/search?q=Tomiyasu",
#                 "promoted_content": null,
#                 "query": "Tomiyasu",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Belotti",
#                 "url": "http://twitter.com/search?q=Belotti",
#                 "promoted_content": null,
#                 "query": "Belotti",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "hobi",
#                 "url": "http://twitter.com/search?q=hobi",
#                 "promoted_content": null,
#                 "query": "hobi",
#                 "tweet_volume": 285701
#             },
#             {
#                 "name": "Ben White",
#                 "url": "http://twitter.com/search?q=%22Ben+White%22",
#                 "promoted_content": null,
#                 "query": "%22Ben+White%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Travis Scott",
#                 "url": "http://twitter.com/search?q=%22Travis+Scott%22",
#                 "promoted_content": null,
#                 "query": "%22Travis+Scott%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Happy New Month",
#                 "url": "http://twitter.com/search?q=%22Happy+New+Month%22",
#                 "promoted_content": null,
#                 "query": "%22Happy+New+Month%22",
#                 "tweet_volume": 84301
#             },
#             {
#                 "name": "ON SALE NOW",
#                 "url": "http://twitter.com/search?q=%22ON+SALE+NOW%22",
#                 "promoted_content": null,
#                 "query": "%22ON+SALE+NOW%22",
#                 "tweet_volume": 16847
#             },
#             {
#                 "name": "Everton",
#                 "url": "http://twitter.com/search?q=Everton",
#                 "promoted_content": null,
#                 "query": "Everton",
#                 "tweet_volume": 49748
#             },
#             {
#                 "name": "Halifax",
#                 "url": "http://twitter.com/search?q=Halifax",
#                 "promoted_content": null,
#                 "query": "Halifax",
#                 "tweet_volume": 12261
#             },
#             {
#                 "name": "Stefan Ortega",
#                 "url": "http://twitter.com/search?q=%22Stefan+Ortega%22",
#                 "promoted_content": null,
#                 "query": "%22Stefan+Ortega%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Lingard",
#                 "url": "http://twitter.com/search?q=Lingard",
#                 "promoted_content": null,
#                 "query": "Lingard",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Claudia Webbe",
#                 "url": "http://twitter.com/search?q=%22Claudia+Webbe%22",
#                 "promoted_content": null,
#                 "query": "%22Claudia+Webbe%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Ederson",
#                 "url": "http://twitter.com/search?q=Ederson",
#                 "promoted_content": null,
#                 "query": "Ederson",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Edgbaston",
#                 "url": "http://twitter.com/search?q=Edgbaston",
#                 "promoted_content": null,
#                 "query": "Edgbaston",
#                 "tweet_volume": 16457
#             },
#             {
#                 "name": "Tour de France",
#                 "url": "http://twitter.com/search?q=%22Tour+de+France%22",
#                 "promoted_content": null,
#                 "query": "%22Tour+de+France%22",
#                 "tweet_volume": 20364
#             },
#             {
#                 "name": "Mary Poppins",
#                 "url": "http://twitter.com/search?q=%22Mary+Poppins%22",
#                 "promoted_content": null,
#                 "query": "%22Mary+Poppins%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Eddie",
#                 "url": "http://twitter.com/search?q=Eddie",
#                 "promoted_content": null,
#                 "query": "Eddie",
#                 "tweet_volume": 186230
#             },
#             {
#                 "name": "Hong Kong",
#                 "url": "http://twitter.com/search?q=%22Hong+Kong%22",
#                 "promoted_content": null,
#                 "query": "%22Hong+Kong%22",
#                 "tweet_volume": 15506
#             },
#             {
#                 "name": "Vinted",
#                 "url": "http://twitter.com/search?q=Vinted",
#                 "promoted_content": null,
#                 "query": "Vinted",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Roger Moore",
#                 "url": "http://twitter.com/search?q=%22Roger+Moore%22",
#                 "promoted_content": null,
#                 "query": "%22Roger+Moore%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Nancy",
#                 "url": "http://twitter.com/search?q=Nancy",
#                 "promoted_content": null,
#                 "query": "Nancy",
#                 "tweet_volume": 93408
#             },
#             {
#                 "name": "Whip",
#                 "url": "http://twitter.com/search?q=Whip",
#                 "promoted_content": null,
#                 "query": "Whip",
#                 "tweet_volume": 64786
#             },
#             {
#                 "name": "Hairdresser",
#                 "url": "http://twitter.com/search?q=Hairdresser",
#                 "promoted_content": null,
#                 "query": "Hairdresser",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "White Rabbits",
#                 "url": "http://twitter.com/search?q=%22White+Rabbits%22",
#                 "promoted_content": null,
#                 "query": "%22White+Rabbits%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Richy",
#                 "url": "http://twitter.com/search?q=Richy",
#                 "promoted_content": null,
#                 "query": "Richy",
#                 "tweet_volume": null
#             }
#         ],
#         "as_of": "2022-07-01T10:14:30Z",
#         "created_at": "2022-06-14T02:54:46Z",
#         "locations": [
#             {
#                 "name": "London",
#                 "woeid": 44418
#             }
#         ]
#     }
# ]

# %%
# Find common topics.
new_york_trends_list = [trend['name'] for trend in new_york_trends[0]['trends']]

# View output.
print(new_york_trends_list)
# Out:
# ['#StrangerThings', 'Eddie', 'Technoblade', 'hoseok', '#jhope_MORE', 'hobi', 'Happy Birthday Jordy', 'hopper', 'Bobby Bonilla', 'robin', 'joyce', 'Jonathan', '#TheBoys', '#fridaymorning', 'Lucas', 'Liberal World Order', 'Cardi', 'dustin', 'byers', '#Wordle377', 'Daily Quordle 158', 'MASTER OF PUPPETS', 'GPII', 'Minecraft', 'michael myers', 'Brenner', 'enzo', 'THE PAINTING', 'Not Netflix', 'Miles Bridges', 'Happy New Month', 'Episode 8', 'Vecna', 'My Netflix', 'Separate Ways', 'Argyle', 'Happy Canada', 'NETFLIX CRASHED', 'Pink Friday', 'Volume 2', 'steve harrington', 'Rex Chapman', 'vickie', 'millie bobby brown', 'Erica', 'NICKI DAY', 'eunwoo', 'david harbour', 'Gary Payton', 'Bino']

# %%
# Find common topics.
london_trends_list = [trend['name'] for trend in london_trends[0]['trends']]

# View output.
print(london_trends_list)
# Out:
# ['Andy Cole', 'Sugababes', 'Morning Steve', 'Spence', 'Jonathan', '#F122', 'Usher', 'hopper', 'Board', '#Spurs', 'Logan', 'Malacia', 'Minions', '#ENGvsIND', '#StrangerThings', 'Technoblade', 'Jota', "They're a 10", 'ticketmaster', 'Somme', 'hoseok', '1st of July', 'Daily Quordle 158', 'Larsson', 'Tomiyasu', 'Belotti', 'hobi', 'Ben White', 'Travis Scott', 'Happy New Month', 'ON SALE NOW', 'Everton', 'Halifax', 'Stefan Ortega', 'Lingard', 'Claudia Webbe', 'Ederson', 'Edgbaston', 'Tour de France', 'Mary Poppins', 'Eddie', 'Hong Kong', 'Vinted', 'Roger Moore', 'Nancy', 'Whip', 'Hairdresser', 'White Rabbits', 'Richy']

# %%
# Find trends between cities.
new_york_trends_set = set(new_york_trends_list)
london_trends_set = set(london_trends_list)

# Set variable.
common_trends = new_york_trends_set.intersection(london_trends_set)

# View output.
print(common_trends)
# Out:
# {'Happy New Month', 'Technoblade', 'Daily Quordle 158', '#StrangerThings', 'hoseok', 'hopper', 'Jonathan', 'Eddie', 'hobi'}

# %% [markdown]
# ## Search for #Bitcoin

# %%
# Run a test with #Bitcoin.
bitcoin_tweets = twitter_api.search.tweets(q="#Bitcoin")

# View JSON output.
print(json.dumps(bitcoin_tweets, indent=4))
# Out:
# {
#     "statuses": [
#         {
#             "created_at": "Fri Jul 01 10:14:44 +0000 2022",
#             "id": 1542813949921357825,
#             "id_str": "1542813949921357825",
#             "text": "RT @Kriptolooo: Birazdan beklenen yeni #asgariucret a\u00e7\u0131klanacak. Yoksulluk s\u0131n\u0131r\u0131m\u0131z ise 21.000 TL olmu\u015f diyeceklerimiz maalesef bu kadar.\u2026",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "asgariucret",
#                         "indices": [
#                             39,
#                             51
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "Kriptolooo",
#                         "name": "Kriptoloji \ud83e\uddd7",
#                         "id": 1342997254131613696,
#                         "id_str": "1342997254131613696",
#                         "indices": [
#                             3,
#                             14
#                         ]
#                     }
#                 ],
#                 "urls": []
#             },
#             "metadata": {
#                 "result_type": "recent",
#                 "iso_language_code": "tr"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1530139688366878722,
#                 "id_str": "1530139688366878722",
#                 "name": "kyle \u2728 manifesting big wins \u2728 #6\ufe0f\u20e35\ufe0f\u20e3\ud83c\udfb9",
#                 "screen_name": "kylesmolbean",
#                 "location": "",
#                 "description": "she/her \ud83c\uddf5\ud83c\udded | #6\ufe0f\u20e35\ufe0f\u20e3\ud83c\udfb9 #ayuminati #GemsWinners #DJ_Winners #deukiess #TenksJo #YnahGives #SUPERGANG",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 18,
#                 "friends_count": 3320,
#                 "listed_count": 0,
#                 "created_at": "Fri May 27 10:51:53 +0000 2022",
#                 "favourites_count": 10779,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 16242,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1542101106901127169/u5t-Y4RH_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1542101106901127169/u5t-Y4RH_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1530139688366878722/1653649718",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Thu Jun 30 13:11:10 +0000 2022",
#                 "id": 1542495964908355586,
#                 "id_str": "1542495964908355586",
#                 "text": "Birazdan beklenen yeni #asgariucret a\u00e7\u0131klanacak. Yoksulluk s\u0131n\u0131r\u0131m\u0131z ise 21.000 TL olmu\u015f diyeceklerimiz maalesef bu\u2026 https://t.co/fpXJkPprVN",
#                 "truncated": true,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "asgariucret",
#                             "indices": [
#                                 23,
#                                 35
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": [
#                         {
#                             "url": "https://t.co/fpXJkPprVN",
#                             "expanded_url": "https://twitter.com/i/web/status/1542495964908355586",
#                             "display_url": "twitter.com/i/web/status/1\u2026",
#                             "indices": [
#                                 117,
#                                 140
#                             ]
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "result_type": "recent",
#                     "iso_language_code": "tr"
#                 },
#                 "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 1342997254131613696,
#                     "id_str": "1342997254131613696",
#                     "name": "Kriptoloji \ud83e\uddd7",
#                     "screen_name": "Kriptolooo",
#                     "location": "T\u00fcrkiye",
#                     "description": "Mustafa Kemal Atat\u00fcrk \u0130zinde \ud83c\uddf9\ud83c\uddf7\n\nPAYLA\u015eIMLARIM YATIRIM TAVS\u0130YES\u0130 DE\u011e\u0130LD\u0130R.\n\n#PlayToEarn #Metaverse #Web30 \n\ud83d\udc49 https://t.co/LAxTacjEC1\n\nkriptoloooji@gmail.com",
#                     "url": "https://t.co/TwOgu3Jr0l",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/TwOgu3Jr0l",
#                                     "expanded_url": "https://instagram.com/kriptolooo/",
#                                     "display_url": "instagram.com/kriptolooo/",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/LAxTacjEC1",
#                                     "expanded_url": "http://t.me/kriiptooloji",
#                                     "display_url": "t.me/kriiptooloji",
#                                     "indices": [
#                                         109,
#                                         132
#                                     ]
#                                 }
#                             ]
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 21188,
#                     "friends_count": 257,
#                     "listed_count": 67,
#                     "created_at": "Sun Dec 27 00:54:43 +0000 2020",
#                     "favourites_count": 12401,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": true,
#                     "verified": false,
#                     "statuses_count": 8452,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "F5F8FA",
#                     "profile_background_image_url": null,
#                     "profile_background_image_url_https": null,
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1529432153053863937/OLwnNnwN_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1529432153053863937/OLwnNnwN_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1342997254131613696/1617968542",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": true,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 170,
#                 "favorite_count": 303,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "tr"
#             },
#             "is_quote_status": false,
#             "retweet_count": 170,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "tr"
#         },
#         {
#             "created_at": "Fri Jul 01 10:14:43 +0000 2022",
#             "id": 1542813947807510528,
#             "id_str": "1542813947807510528",
#             "text": "RT @infinity_kripto: Bug\u00fcn\u00fcn \u015eerefine \ud83e\udd73\ud83e\udd73\ud83e\udd73\n\n100 #USDT \u00c7ekili\u015f \u015eansl\u0131 2 Ki\u015fi \n\nTakip et : @infinity_kripto\n\nBu tweeti RT yapan 2  takip\u00e7ime d\u2026",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "USDT",
#                         "indices": [
#                             47,
#                             52
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "infinity_kripto",
#                         "name": "\u0130nfinity | Bull Trade",
#                         "id": 1269127893201891328,
#                         "id_str": "1269127893201891328",
#                         "indices": [
#                             3,
#                             19
#                         ]
#                     },
#                     {
#                         "screen_name": "infinity_kripto",
#                         "name": "\u0130nfinity | Bull Trade",
#                         "id": 1269127893201891328,
#                         "id_str": "1269127893201891328",
#                         "indices": [
#                             88,
#                             104
#                         ]
#                     }
#                 ],
#                 "urls": []
#             },
#             "metadata": {
#                 "result_type": "recent",
#                 "iso_language_code": "tr"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1542770584924217345,
#                 "id_str": "1542770584924217345",
#                 "name": "Q",
#                 "screen_name": "Q69972185",
#                 "location": "",
#                 "description": "",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 0,
#                 "friends_count": 0,
#                 "listed_count": 0,
#                 "created_at": "Fri Jul 01 07:22:29 +0000 2022",
#                 "favourites_count": 0,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 66,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#                 "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": true,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Wed Jun 29 23:01:05 +0000 2022",
#                 "id": 1542282030783799297,
#                 "id_str": "1542282030783799297",
#                 "text": "Bug\u00fcn\u00fcn \u015eerefine \ud83e\udd73\ud83e\udd73\ud83e\udd73\n\n100 #USDT \u00c7ekili\u015f \u015eansl\u0131 2 Ki\u015fi \n\nTakip et : @infinity_kripto\n\nBu tweeti RT yapan 2  takip\u00e7im\u2026 https://t.co/N1QC67NMZa",
#                 "truncated": true,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "USDT",
#                             "indices": [
#                                 26,
#                                 31
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [
#                         {
#                             "screen_name": "infinity_kripto",
#                             "name": "\u0130nfinity | Bull Trade",
#                             "id": 1269127893201891328,
#                             "id_str": "1269127893201891328",
#                             "indices": [
#                                 67,
#                                 83
#                             ]
#                         }
#                     ],
#                     "urls": [
#                         {
#                             "url": "https://t.co/N1QC67NMZa",
#                             "expanded_url": "https://twitter.com/i/web/status/1542282030783799297",
#                             "display_url": "twitter.com/i/web/status/1\u2026",
#                             "indices": [
#                                 117,
#                                 140
#                             ]
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "result_type": "recent",
#                     "iso_language_code": "tr"
#                 },
#                 "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 1269127893201891328,
#                     "id_str": "1269127893201891328",
#                     "name": "\u0130nfinity | Bull Trade",
#                     "screen_name": "infinity_kripto",
#                     "location": "",
#                     "description": "Crypto Trade Community l \nPayla\u015f\u0131mlar\u0131m Yat\u0131r\u0131m Tavsiyesi De\u011fildir.\n\n#Btc #Bnb #Usdt",
#                     "url": "https://t.co/YYUNKYrRwy",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/YYUNKYrRwy",
#                                     "expanded_url": "http://linktr.ee/bulltradekripto",
#                                     "display_url": "linktr.ee/bulltradekripto",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 1081,
#                     "friends_count": 120,
#                     "listed_count": 2,
#                     "created_at": "Sat Jun 06 04:44:10 +0000 2020",
#                     "favourites_count": 181,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": false,
#                     "verified": false,
#                     "statuses_count": 80,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "F5F8FA",
#                     "profile_background_image_url": null,
#                     "profile_background_image_url_https": null,
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1535571537755099136/hSdLCI4J_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1535571537755099136/hSdLCI4J_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1269127893201891328/1656623883",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": false,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": true,
#                 "quoted_status_id": 1542280845150621696,
#                 "quoted_status_id_str": "1542280845150621696",
#                 "quoted_status": {
#                     "created_at": "Wed Jun 29 22:56:22 +0000 2022",
#                     "id": 1542280845150621696,
#                     "id_str": "1542280845150621696",
#                     "text": "#KAVA %55\n#ARPA %55\n#LPT %50\n#OP %40\n#SRM %30 \n\nBug\u00fcn 5/5  \u2705\u2705. \ud83d\udd25\ud83d\udd25\n\n#BTC #Binance",
#                     "truncated": false,
#                     "entities": {
#                         "hashtags": [
#                             {
#                                 "text": "KAVA",
#                                 "indices": [
#                                     0,
#                                     5
#                                 ]
#                             },
#                             {
#                                 "text": "ARPA",
#                                 "indices": [
#                                     10,
#                                     15
#                                 ]
#                             },
#                             {
#                                 "text": "LPT",
#                                 "indices": [
#                                     20,
#                                     24
#                                 ]
#                             },
#                             {
#                                 "text": "OP",
#                                 "indices": [
#                                     29,
#                                     32
#                                 ]
#                             },
#                             {
#                                 "text": "SRM",
#                                 "indices": [
#                                     37,
#                                     41
#                                 ]
#                             },
#                             {
#                                 "text": "BTC",
#                                 "indices": [
#                                     67,
#                                     71
#                                 ]
#                             },
#                             {
#                                 "text": "Binance",
#                                 "indices": [
#                                     72,
#                                     80
#                                 ]
#                             }
#                         ],
#                         "symbols": [],
#                         "user_mentions": [],
#                         "urls": []
#                     },
#                     "metadata": {
#                         "result_type": "recent",
#                         "iso_language_code": "tr"
#                     },
#                     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#                     "in_reply_to_status_id": null,
#                     "in_reply_to_status_id_str": null,
#                     "in_reply_to_user_id": null,
#                     "in_reply_to_user_id_str": null,
#                     "in_reply_to_screen_name": null,
#                     "user": {
#                         "id": 1269127893201891328,
#                         "id_str": "1269127893201891328",
#                         "name": "\u0130nfinity | Bull Trade",
#                         "screen_name": "infinity_kripto",
#                         "location": "",
#                         "description": "Crypto Trade Community l \nPayla\u015f\u0131mlar\u0131m Yat\u0131r\u0131m Tavsiyesi De\u011fildir.\n\n#Btc #Bnb #Usdt",
#                         "url": "https://t.co/YYUNKYrRwy",
#                         "entities": {
#                             "url": {
#                                 "urls": [
#                                     {
#                                         "url": "https://t.co/YYUNKYrRwy",
#                                         "expanded_url": "http://linktr.ee/bulltradekripto",
#                                         "display_url": "linktr.ee/bulltradekripto",
#                                         "indices": [
#                                             0,
#                                             23
#                                         ]
#                                     }
#                                 ]
#                             },
#                             "description": {
#                                 "urls": []
#                             }
#                         },
#                         "protected": false,
#                         "followers_count": 1081,
#                         "friends_count": 120,
#                         "listed_count": 2,
#                         "created_at": "Sat Jun 06 04:44:10 +0000 2020",
#                         "favourites_count": 181,
#                         "utc_offset": null,
#                         "time_zone": null,
#                         "geo_enabled": false,
#                         "verified": false,
#                         "statuses_count": 80,
#                         "lang": null,
#                         "contributors_enabled": false,
#                         "is_translator": false,
#                         "is_translation_enabled": false,
#                         "profile_background_color": "F5F8FA",
#                         "profile_background_image_url": null,
#                         "profile_background_image_url_https": null,
#                         "profile_background_tile": false,
#                         "profile_image_url": "http://pbs.twimg.com/profile_images/1535571537755099136/hSdLCI4J_normal.jpg",
#                         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1535571537755099136/hSdLCI4J_normal.jpg",
#                         "profile_banner_url": "https://pbs.twimg.com/profile_banners/1269127893201891328/1656623883",
#                         "profile_link_color": "1DA1F2",
#                         "profile_sidebar_border_color": "C0DEED",
#                         "profile_sidebar_fill_color": "DDEEF6",
#                         "profile_text_color": "333333",
#                         "profile_use_background_image": true,
#                         "has_extended_profile": false,
#                         "default_profile": true,
#                         "default_profile_image": false,
#                         "following": false,
#                         "follow_request_sent": false,
#                         "notifications": false,
#                         "translator_type": "none",
#                         "withheld_in_countries": []
#                     },
#                     "geo": null,
#                     "coordinates": null,
#                     "place": null,
#                     "contributors": null,
#                     "is_quote_status": false,
#                     "retweet_count": 2,
#                     "favorite_count": 5,
#                     "favorited": false,
#                     "retweeted": false,
#                     "lang": "tr"
#                 },
#                 "retweet_count": 156,
#                 "favorite_count": 22,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "tr"
#             },
#             "is_quote_status": true,
#             "quoted_status_id": 1542280845150621696,
#             "quoted_status_id_str": "1542280845150621696",
#             "retweet_count": 156,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "tr"
#         },
#         {
#             "created_at": "Fri Jul 01 10:14:43 +0000 2022",
#             "id": 1542813946666696708,
#             "id_str": "1542813946666696708",
#             "text": "RT @BitcoinMagazine: JUST IN - \ud83c\udde8\ud83c\uddeb Central African Republic President: #Bitcoin adoption will accelerate the evolution of the human species",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             70,
#                             78
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "BitcoinMagazine",
#                         "name": "Bitcoin Magazine",
#                         "id": 361289499,
#                         "id_str": "361289499",
#                         "indices": [
#                             3,
#                             19
#                         ]
#                     }
#                 ],
#                 "urls": []
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 2561610723,
#                 "id_str": "2561610723",
#                 "name": "Adam Moody",
#                 "screen_name": "Adam_Moody4",
#                 "location": "Sheffield, England",
#                 "description": "Blade | #Bitcoin | Web Developer",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 2093,
#                 "friends_count": 5001,
#                 "listed_count": 33,
#                 "created_at": "Sat May 24 08:18:07 +0000 2014",
#                 "favourites_count": 308027,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": false,
#                 "statuses_count": 209420,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1392976434138865672/IX3Gq95E_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1392976434138865672/IX3Gq95E_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/2561610723/1609173338",
#                 "profile_link_color": "8E1FD9",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Thu Jun 30 22:03:14 +0000 2022",
#                 "id": 1542629863089008640,
#                 "id_str": "1542629863089008640",
#                 "text": "JUST IN - \ud83c\udde8\ud83c\uddeb Central African Republic President: #Bitcoin adoption will accelerate the evolution of the human species",
#                 "truncated": false,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "Bitcoin",
#                             "indices": [
#                                 49,
#                                 57
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": []
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 361289499,
#                     "id_str": "361289499",
#                     "name": "Bitcoin Magazine",
#                     "screen_name": "BitcoinMagazine",
#                     "location": "Nashville, TN",
#                     "description": "The Most Trusted Voice In #Bitcoin \u2022  World's Largest Bitcoin Conference \ud83c\udf9f https://t.co/hBUM3ottXO \u2022 Shop \ud83d\udcd7 https://t.co/v3sTyHVZKV \u2022 Find us \ud83d\udd0e https://t.co/X4mXn3XUAg",
#                     "url": "https://t.co/UPj0DC9NOU",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/UPj0DC9NOU",
#                                     "expanded_url": "http://BitcoinMagazine.com",
#                                     "display_url": "BitcoinMagazine.com",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/hBUM3ottXO",
#                                     "expanded_url": "http://b.tc/conference/2023",
#                                     "display_url": "b.tc/conference/2023",
#                                     "indices": [
#                                         75,
#                                         98
#                                     ]
#                                 },
#                                 {
#                                     "url": "https://t.co/v3sTyHVZKV",
#                                     "expanded_url": "http://b.tc/store",
#                                     "display_url": "b.tc/store",
#                                     "indices": [
#                                         108,
#                                         131
#                                     ]
#                                 },
#                                 {
#                                     "url": "https://t.co/X4mXn3XUAg",
#                                     "expanded_url": "http://linktr.ee/btcinc",
#                                     "display_url": "linktr.ee/btcinc",
#                                     "indices": [
#                                         144,
#                                         167
#                                     ]
#                                 }
#                             ]
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 2549647,
#                     "friends_count": 771,
#                     "listed_count": 13928,
#                     "created_at": "Wed Aug 24 15:14:54 +0000 2011",
#                     "favourites_count": 25893,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": true,
#                     "verified": true,
#                     "statuses_count": 23847,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "000000",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1444022922377576453/AzvXYXGr_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1444022922377576453/AzvXYXGr_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/361289499/1655991595",
#                     "profile_link_color": "FFA207",
#                     "profile_sidebar_border_color": "000000",
#                     "profile_sidebar_fill_color": "000000",
#                     "profile_text_color": "000000",
#                     "profile_use_background_image": false,
#                     "has_extended_profile": false,
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "regular",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 307,
#                 "favorite_count": 2124,
#                 "favorited": false,
#                 "retweeted": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 307,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Fri Jul 01 10:14:43 +0000 2022",
#             "id": 1542813946448556032,
#             "id_str": "1542813946448556032",
#             "text": "RT @BTC_Archive: \u201cThank you for selling cheap,\u201d says President of El Salvador \n\n#Bitcoin https://t.co/2IVRU88CDc",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "Bitcoin",
#                         "indices": [
#                             80,
#                             88
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [
#                     {
#                         "screen_name": "BTC_Archive",
#                         "name": "Bitcoin Archive \ud83d\uddc4\ud83d\ude80\ud83c\udf14",
#                         "id": 970994516357472257,
#                         "id_str": "970994516357472257",
#                         "indices": [
#                             3,
#                             15
#                         ]
#                     }
#                 ],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1542796268602363905,
#                         "id_str": "1542796268602363905",
#                         "indices": [
#                             89,
#                             112
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FWkdCD7XkAEsw3S.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FWkdCD7XkAEsw3S.jpg",
#                         "url": "https://t.co/2IVRU88CDc",
#                         "display_url": "pic.twitter.com/2IVRU88CDc",
#                         "expanded_url": "https://twitter.com/BTC_Archive/status/1542796275489415169/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "small": {
#                                 "w": 680,
#                                 "h": 381,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1180,
#                                 "h": 662,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1180,
#                                 "h": 662,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1542796275489415169,
#                         "source_status_id_str": "1542796275489415169",
#                         "source_user_id": 970994516357472257,
#                         "source_user_id_str": "970994516357472257"
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1542796268602363905,
#                         "id_str": "1542796268602363905",
#                         "indices": [
#                             89,
#                             112
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FWkdCD7XkAEsw3S.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FWkdCD7XkAEsw3S.jpg",
#                         "url": "https://t.co/2IVRU88CDc",
#                         "display_url": "pic.twitter.com/2IVRU88CDc",
#                         "expanded_url": "https://twitter.com/BTC_Archive/status/1542796275489415169/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "small": {
#                                 "w": 680,
#                                 "h": 381,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1180,
#                                 "h": 662,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1180,
#                                 "h": 662,
#                                 "resize": "fit"
#                             }
#                         },
#                         "source_status_id": 1542796275489415169,
#                         "source_status_id_str": "1542796275489415169",
#                         "source_user_id": 970994516357472257,
#                         "source_user_id_str": "970994516357472257"
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1098890753491619840,
#                 "id_str": "1098890753491619840",
#                 "name": "Subcutaneous Crypto",
#                 "screen_name": "subcutcrypto",
#                 "location": "",
#                 "description": "",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 45,
#                 "friends_count": 172,
#                 "listed_count": 5,
#                 "created_at": "Fri Feb 22 10:22:26 +0000 2019",
#                 "favourites_count": 1363,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 166,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1494330649049657349/cxY32npY_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1494330649049657349/cxY32npY_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1098890753491619840/1643775027",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Fri Jul 01 09:04:30 +0000 2022",
#                 "id": 1542796275489415169,
#                 "id_str": "1542796275489415169",
#                 "text": "\u201cThank you for selling cheap,\u201d says President of El Salvador \n\n#Bitcoin https://t.co/2IVRU88CDc",
#                 "truncated": false,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "Bitcoin",
#                             "indices": [
#                                 63,
#                                 71
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": [],
#                     "media": [
#                         {
#                             "id": 1542796268602363905,
#                             "id_str": "1542796268602363905",
#                             "indices": [
#                                 72,
#                                 95
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/FWkdCD7XkAEsw3S.jpg",
# ...
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1423779327477534731,
#                 "id_str": "1423779327477534731",
#                 "name": "Sl\u00edmz\u303d\ufe0f",
#                 "screen_name": "justin10_eze",
#                 "location": "042 HQ\u2022\u2022\u2022",
#                 "description": "\u00b0\u00b0Cool Gee \ud83e\udd2a\u00b0\u00b0\n#PAW #XRD #HBIT #ban #ants\n\nhttps://t.co/wy1eOQzOpG",
#                 "url": null,
#                 "entities": {
#                     "description": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/wy1eOQzOpG",
#                                 "expanded_url": "https://paw.digital/",
#                                 "display_url": "paw.digital",
#                                 "indices": [
#                                     43,
#                                     66
#                                 ]
#                             }
#                         ]
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 88,
#                 "friends_count": 417,
#                 "listed_count": 8,
#                 "created_at": "Fri Aug 06 22:54:06 +0000 2021",
#                 "favourites_count": 2099,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 900,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1534797700713041920/VxOIZDSS_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1534797700713041920/VxOIZDSS_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1423779327477534731/1652335462",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "retweeted_status": {
#                 "created_at": "Thu Jun 30 19:03:42 +0000 2022",
#                 "id": 1542584679609647105,
#                 "id_str": "1542584679609647105",
#                 "text": "#HBIT #Blockchain #Learn to #Earn App is now available on #Google #playstore \n\nhttps://t.co/lK50T1DMfp\n\nContest Sta\u2026 https://t.co/TKGj4jmNWg",
#                 "truncated": true,
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "text": "HBIT",
#                             "indices": [
#                                 0,
#                                 5
#                             ]
#                         },
#                         {
#                             "text": "Blockchain",
#                             "indices": [
#                                 6,
#                                 17
#                             ]
#                         },
#                         {
#                             "text": "Learn",
#                             "indices": [
#                                 18,
#                                 24
#                             ]
#                         },
#                         {
#                             "text": "Earn",
#                             "indices": [
#                                 28,
#                                 33
#                             ]
#                         },
#                         {
#                             "text": "Google",
#                             "indices": [
#                                 58,
#                                 65
#                             ]
#                         },
#                         {
#                             "text": "playstore",
#                             "indices": [
#                                 66,
#                                 76
#                             ]
#                         }
#                     ],
#                     "symbols": [],
#                     "user_mentions": [],
#                     "urls": [
#                         {
#                             "url": "https://t.co/lK50T1DMfp",
#                             "expanded_url": "https://play.google.com/store/apps/details?id=learn.earn.hashbit",
#                             "display_url": "play.google.com/store/apps/det\u2026",
#                             "indices": [
#                                 79,
#                                 102
#                             ]
#                         },
#                         {
#                             "url": "https://t.co/TKGj4jmNWg",
#                             "expanded_url": "https://twitter.com/i/web/status/1542584679609647105",
#                             "display_url": "twitter.com/i/web/status/1\u2026",
#                             "indices": [
#                                 117,
#                                 140
#                             ]
#                         }
#                     ]
#                 },
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "in_reply_to_screen_name": null,
#                 "user": {
#                     "id": 1370763938883846152,
#                     "id_str": "1370763938883846152",
#                     "name": "HashBit BlockChain",
#                     "screen_name": "HashBitorg",
#                     "location": "Milano, Lombardia",
#                     "description": "#HBIT #BlockChain any #Browser any #Device Easy to Use and Extreme Fast! https://t.co/eE6bVF8CFa",
#                     "url": "https://t.co/x70mwCYJXo",
#                     "entities": {
#                         "url": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/x70mwCYJXo",
#                                     "expanded_url": "https://hashbit.org",
#                                     "display_url": "hashbit.org",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ]
#                                 }
#                             ]
#                         },
#                         "description": {
#                             "urls": [
#                                 {
#                                     "url": "https://t.co/eE6bVF8CFa",
#                                     "expanded_url": "http://t.me/hashbitofficial",
#                                     "display_url": "t.me/hashbitofficial",
#                                     "indices": [
#                                         73,
#                                         96
#                                     ]
#                                 }
#                             ]
#                         }
#                     },
#                     "protected": false,
#                     "followers_count": 24108,
#                     "friends_count": 149,
#                     "listed_count": 8,
#                     "created_at": "Sat Mar 13 15:49:38 +0000 2021",
#                     "favourites_count": 456,
#                     "utc_offset": null,
#                     "time_zone": null,
#                     "geo_enabled": false,
#                     "verified": false,
#                     "statuses_count": 558,
#                     "lang": null,
#                     "contributors_enabled": false,
#                     "is_translator": false,
#                     "is_translation_enabled": false,
#                     "profile_background_color": "F5F8FA",
#                     "profile_background_image_url": null,
#                     "profile_background_image_url_https": null,
#                     "profile_background_tile": false,
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/1409601459147128835/pq8Y7ZIu_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1409601459147128835/pq8Y7ZIu_normal.jpg",
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1370763938883846152/1639998049",
#                     "profile_link_color": "1DA1F2",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "has_extended_profile": true,
#                     "default_profile": true,
#                     "default_profile_image": false,
#                     "following": false,
#                     "follow_request_sent": false,
#                     "notifications": false,
#                     "translator_type": "none",
#                     "withheld_in_countries": []
#                 },
#                 "geo": null,
#                 "coordinates": null,
#                 "place": null,
#                 "contributors": null,
#                 "is_quote_status": false,
#                 "retweet_count": 6,
#                 "favorite_count": 20,
#                 "favorited": false,
#                 "retweeted": false,
#                 "possibly_sensitive": false,
#                 "lang": "en"
#             },
#             "is_quote_status": false,
#             "retweet_count": 6,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         {
#             "created_at": "Fri Jul 01 10:14:36 +0000 2022",
#             "id": 1542813918246178818,
#             "id_str": "1542813918246178818",
#             "text": "Kimler online? \ud83d\udc40\u2764\n\n#bitcoin",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "bitcoin",
#                         "indices": [
#                             19,
#                             27
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": []
#             },
#             "metadata": {
#                 "result_type": "recent",
#                 "iso_language_code": "tr"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1378655509964816386,
#                 "id_str": "1378655509964816386",
#                 "name": "PersonelTra(i)der\ud83d\udcca",
#                 "screen_name": "Personeltrader",
#                 "location": "",
#                 "description": "\ud83d\udcccYat\u0131r\u0131m tavsiyesi de\u011fil tamamen bilgilendirme ama\u00e7l\u0131 analizler at\u0131yorum. Telegram; https://t.co/CRFY1Ui2ra\n\n\u0130leti\u015fim: personeltrader@gmail.com",
#                 "url": "https://t.co/fFCzx9jgUS",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/fFCzx9jgUS",
#                                 "expanded_url": "https://www.binance.com/tr/register?ref=Z16RA67I",
#                                 "display_url": "binance.com/tr/register?re\u2026",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/CRFY1Ui2ra",
#                                 "expanded_url": "https://t.me/personeltrader",
#                                 "display_url": "t.me/personeltrader",
#                                 "indices": [
#                                     84,
#                                     107
#                                 ]
#                             }
#                         ]
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 9389,
#                 "friends_count": 89,
#                 "listed_count": 32,
#                 "created_at": "Sun Apr 04 10:27:49 +0000 2021",
#                 "favourites_count": 65787,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": false,
#                 "statuses_count": 6858,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1532763021801574400/DAPKO8Bs_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1532763021801574400/DAPKO8Bs_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 0,
#             "favorite_count": 0,
#             "favorited": false,
#             "retweeted": false,
#             "lang": "tr"
#         }
#     ],
#     "search_metadata": {
#         "completed_in": 0.088,
#         "max_id": 1542813949921357825,
#         "max_id_str": "1542813949921357825",
#         "next_results": "?max_id=1542813918246178817&q=%23Bitcoin&include_entities=1",
#         "query": "%23Bitcoin",
#         "refresh_url": "?since_id=1542813949921357825&q=%23Bitcoin&include_entities=1",
#         "count": 15,
#         "since_id": 0,
#         "since_id_str": "0"
#     }
# }
